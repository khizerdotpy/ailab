# %%
print("they see me rolling,they hating")
# Out:
# they see me rolling,they hating

# %%
intd=100
stringname="lawrence"

print(f"his name is {stringname} and his age is {intd}.")
# Out:
# his name is lawrence and his age is 100.

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
print(f"his name is {name} and his age is {age}.")
# Out:
# Enter your name:  lawrence
# Enter your age:  12
# his name is lawrence and his age is 12.

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
comp=14+4j
print(type(comp))
# Out:
# <class 'complex'>

# %%
print(name[0])
# Out:
# l

# %%
print(name[1:4])
# Out:
# awr

# %%
print(name[0:])
# Out:
# lawrence

# %%
print(name + " crow")
# Out:
# lawrence crow

# %%
setdata={"haassaan","maha",45.9,12}
print(f"set: {setdata}")
# Out:
# set: {'haassaan', 12, 45.9, 'maha'}

# %%
mylist=[100,200,300,400]

print(f"second element of list: {mylist[1]}")
# Out:
# second element of list: 200

# %%
mylist[3]=500
print(f"last element of list: {mylist[3]}")
# Out:
# last element of list: 500

# %% [markdown]
# // it will give error

# %%
mytuple=(100,200,300,400)
mytuple[3]=500
print(f"last element of list: {mylist[3]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 mytuple=(100,200,300,400)
# ----> 2 mytuple[3]=500
#       3 print(f"last element of list: {mylist[3]}")
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(mylist)
# Out:
# [100, 200, 300, 500]

# %%
del mylist[2]
print(f"after deletion: {mylist}")
# Out:
# after deletion: [100, 200, 500]

# %%
mydict= {'name':'lawrence','title':'crow'}
print(mydict)
print(mydict.keys())
print(mydict.values())
# Out:
# {'name': 'lawrence', 'title': 'crow'}
# dict_keys(['name', 'title'])
# dict_values(['lawrence', 'crow'])

# %%
if age>10:
    print(f"{age} is greater than 10")
# Out:
# 12 is greater than 10

# %%
if age>10:
print(f"{age} is greater than 10")
# Out:
#   Cell In[19], line 2
#     print(f"{age} is greater than 10")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if age>10:
    print(f"{age} is greater than 10")
else:
    print("lesser than 10")
# Out:
# 12 is greater than 10

# %%
perc=float(input("Enter inter percentage"))

if perc >=80:
    print("eligible for SE and AI")
elif perc >=70:
    print("eligible for CS and DS")
elif perc >=60:
    print("eligible for cybersecurity")
else:
    print("ineligible")
# Out:
# Enter inter percentage 80
# eligible for SE and AI

# %%
print(mylist)
# Out:
# [100, 200, 500]

# %%
del mylist[3]
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 del mylist[3]
#       2 print(mylist)
#
# IndexError: list assignment index out of range

# %%
for var in mylist(range(4)):
    print(var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 for var in mylist(range(4)):
#       2     print(var)
#
# TypeError: 'list' object is not callable

# %%
mylist
# Out:
# [100, 200, 500]

# %%
for var in mylist:
    print(var)
# Out:
# 100
# 200
# 500

# %%
for i in range(3):
    print(mylist[i])
# Out:
# 100
# 200
# 500

# %% [markdown]
# # count=0
#
# while(count<len(mylist)):
#     print(mylist[count])
#     count=count+0

# %%
count=0

while(count<len(mylist)):
    print(mylist[count])
    count=count+1
# Out:
# 100
# 200
# 500

# %%
def non_paraFunc ():
  print("This is Non_parametric Function")

non_paraFunc()
# Out:
# This is Non_parametric Function

# %%
def paraFunc (a,b):
  return a + b

paraFunc(1,2)
# Out:
# 3

# %% [markdown]
# ### dict

# %%
mydict
# Out:
# {'name': 'lawrence', 'title': 'crow'}

# %%
mydict2= {'name': 'lawrence', 'age': 39}
mydict3= {'name': 'hammad', 'age': 11}

# %%
print(mydict2['age']+mydict3['age'])
# Out:
# 50
