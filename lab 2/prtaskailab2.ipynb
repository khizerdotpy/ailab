# %% [markdown]
# <a href="https://colab.research.google.com/github/khizerdotpy/ailab/blob/main/lab%202/prtaskailab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class lights:
  def __init__(self,roomn,st):
    self.room_name=roomn
    self.status=st

  def onfunc(self):
    status=True
    print(f"light for room: {self.room_name} turned {'ON' if self.status==True else 'OFF'}")


  def offfunc(self):
    status=False
    print(f"light for room: {self.room_name} turned {'OFF' if self.status==False else 'ON'}")

  def getStatus(self):
    print(f"Current Status is: {self.status}")






livingroom= lights("Living Room","OFF")
bedroom= lights("Bedroom","OFF")

livingroom.onfunc()
bedroom.offfunc()
livingroom.getStatus()
bedroom.getStatus()
# Out:
# light for room: Living Room turned OFF
# light for room: Bedroom turned ON
# Current Status is: OFF
# Current Status is: OFF

# %% [markdown]
# practice task 2

# %%
class Staff:
  def __init__(self,nm,id,dpt):
    self.name=nm
    self.staff_id=id
    self.department=dpt


class Teacher(Staff):
  def __init__(self,crs,sal):
    self.course=crs
    self.salary=sal
    super().__init__()

  def teachcourse(self):
    print(f"{Teacher.name} teaches {self.course}")


class Admin(Staff):
  def __init__(self,rol,whours,task):
    self.role=rol
    self.working_hours=whours
    self.tasks=task
    super().__init__()

  class Research_Assistant(Staff):
    def __init__(self,rtpc,st,wrk):
      self.research_topic=rtpc
      self.stipend=st
