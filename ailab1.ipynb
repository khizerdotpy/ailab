# %% [markdown]
# <a href="https://colab.research.google.com/github/khizerdotpy/ailab/blob/main/ailab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("they see me rolling,they hating")
# Out:
# they see me rolling,they hating

# %%
intd=100
stringname="lawrence"

print(f"his name is {stringname} and his age is {intd}.")
# Out:
# his name is lawrence and his age is 100.

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
print(f"his name is {name} and his age is {age}.")
# Out:
# Enter your name: lawrence
# Enter your age: 20
# his name is lawrence and his age is 20.

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
comp=14+4j
print(type(comp))
# Out:
# <class 'complex'>
